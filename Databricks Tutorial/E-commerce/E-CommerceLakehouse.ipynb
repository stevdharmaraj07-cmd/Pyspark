# %%
# Read files
df_customers = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/customers.csv",header=True, inferSchema=True)
df_countries = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/countries.csv",header=True, inferSchema=True)
df_customer_updates = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/customers.csv",header=True, inferSchema=True)
df_data_quality_issues = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/data_quality_issues.csv",header=True, inferSchema=True)
df_order_items = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/order_items.csv",header=True, inferSchema=True)
df_orders = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/orders.csv",header=True, inferSchema=True)
df_orders_incremental = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/orders_incremental.csv",header=True, inferSchema=True)
df_payments = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/payments.csv",header=True, inferSchema=True)
df_products = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/products.csv",header=True, inferSchema=True)
df_suppliers = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/suppliers.csv",header=True, inferSchema=True)
df_website_events = spark.read.csv("/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/website_events.csv",header=True, inferSchema=True)

# Display the combined result
display(df_customers)

# %%
display(df_customer_updates)

# %%
df_customers = df_customers.union(df_customer_updates).distinct().display()

# %%
# Define connection variables
server_name = "DESKTOP-2CRP10S" # Do not use 'localhost'
port = "1433" # Default SQL Server port
database_name = "HR"
username = "stephen"
password = "We@re1nj@n2501" # See security note below

# Construct the JDBC URL
jdbc_url = f"jdbc:sqlserver://{server_name}:{port};databaseName={database_name}"

# Define connection properties
connection_properties = {
    "stephen": username,
    "We@re1nj@n2501": password,
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
# Fix connection properties - they need "user" and "password" as keys
connection_properties_fixed = {
    "user": username,
    "password": password,
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

table_name = "dbo.employees"

# Read the data
df = spark.read.jdbc(url=jdbc_url, table=table_name, properties=connection_properties_fixed)

# Display the data in your notebook
display(df)
