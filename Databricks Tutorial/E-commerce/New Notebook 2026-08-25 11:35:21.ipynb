# %%
files = dbutils.fs.ls(
    "/Volumes/databrickstutorial/default/data/pyspark_ecommerce_project_datasets/"
)

for file in files:
    print(file.name)
    csv_dataframes = {}

# %%
df = csv_dataframes["countries"]

df.show()
